# %%
import pandas as pd
import numpy as np

# %%
reportsjan_feb =pd.read_excel("For_Pandas_Original_DF.xlsx", sheet_name = "внешный")
jan_feb_2022_reports = pd.read_excel("For_Pandas_Original_DF.xlsx")
reportsjan_feb.head(2)
#reportsjan_feb.dtypes
# Out:
#        Код       Дата  № док  Поставщик                 Наименование    Абрев  \
# 0  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 250/10кВТ  30363.0
# 1  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 630/10кВТ  30364.0
#
#          Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0  Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  Электроматериалы     шт     1.0  118255.0  118255.0   NaT   NaN
#
#                                               Произ.  МНН           Вопросы  \
# 0  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 1  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
#
#   Unnamed: 16
# 0         NaN
# 1         NaN

# %%
# I want to delete only rows that have the name "Внш Давид"
delete_david = reportsjan_feb["Поставщик"]== "Внш Давид"
reportsjan_feb.drop(index= reportsjan_feb[delete_david].index)
# Out:
#          Код       Дата  № док            Поставщик  \
# 13   27868.0 2022-01-01    1.0          Внш Хувайдо
# 14   27868.0 2022-01-01    1.0          Внш Хувайдо
# 15   27868.0 2022-01-01    1.0          Внш Хувайдо
# 16   27868.0 2022-01-01    1.0          Внш Хувайдо
# 17   27868.0 2022-01-01    1.0          Внш Хувайдо
# ..       ...        ...    ...                  ...
# 254  28896.0 2022-02-22    1.0  Внш Хайруллоев Боир
# 255  28898.0 2022-02-28    1.0  Внш Хайруллоев Боир
# 256      NaN        NaT    NaN                  NaN
# 257      NaN        NaT    NaN                  NaN
# 258      NaN        NaT    NaN                  NaN
#
#                                         Наименование    Абрев  \
# 13              Футеровка (№ черт. 02.590.00.01) 591  18812.0
# 14              Футеровка (№ черт. 02.590.00.02) 592  18813.0
# 15              Футеровка (№ черт. 02.590.00.03) 593  18814.0
# 16   Футеровка торцевая ( № черт. 1348.02.201СБ) 201  18815.0
# ...

# %%
# Drop index, rows not columns
reportsjan_feb.drop(index=[0],inplace=True)

# %%
# Adding values from tbl A to tbl B, that's what I am stuck at?!

# %%
# Add a new row of data via .append()
reportsjan_feb.append({"Поставщик":"Anushervon"},ignore_index=True)
# Out:
# C:\Users\User-PC\AppData\Local\Temp\ipykernel_4036\2967647725.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reportsjan_feb.append({"Поставщик":"Anushervon"},ignore_index=True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User-PC\Desktop\Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb Cell 3' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000024?line=0'>1</a> # Add a new row of data via .append()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000024?line=1'>2</a> reportsjan_feb.append({"Поставщик":"Anushervon"},ignore_index=True)
# ...

# %%
# Add Multiple Columns in a one line of code
reportsjan_feb[["Name1","Name2""Name3"]] = reportsjan_feb["Сумма"] /reportsjan_feb["Сумма"].sum()
reportsjan_feb.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\User-PC\Desktop\Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000023?line=0'>1</a> # Add Multiple Columns in a one line of code
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000023?line=1'>2</a> reportsjan_feb[["Name1","Name2""Name3"]] = reportsjan_feb["Сумма"] /reportsjan_feb["Сумма"].sum()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000023?line=2'>3</a> reportsjan_feb.head()
#
# ...

# %%
# Drop not needed columns
reportsjan_feb.drop(columns=["Unnamed: 16"],inplace=True)
reportsjan_feb.head(2)
# Out:
#        Код       Дата  № док  Поставщик                 Наименование    Абрев  \
# 0  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 250/10кВТ  30363.0
# 1  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 630/10кВТ  30364.0
#
#          Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0  Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  Электроматериалы     шт     1.0  118255.0  118255.0   NaT   NaN
#
#                                               Произ.  МНН           Вопросы
# 0  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 1  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм

# %%
# Let's add a new column
reportsjan_feb["Name_Splitted"] = reportsjan_feb["Наименование"].str.split(expand=True)[0]
reportsjan_feb.head(3)
# Out:
#        Код       Дата  № док  Поставщик                 Наименование    Абрев  \
# 0  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 250/10кВТ  30363.0
# 1  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 630/10кВТ  30364.0
# 2  27654.0 2022-01-01    1.0  Внш Давид   Трансформатор ТМГ 100/6кВТ  30365.0
#
#          Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0  Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  Электроматериалы     шт     1.0  118255.0  118255.0   NaT   NaN
# 2  Электроматериалы     шт     1.0   42275.0   42275.0   NaT   NaN
#
#                                               Произ.  МНН           Вопросы  \
# 0  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 1  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 2  Чирчикский трансформаторный завод  Контракт:TG...  NaN          Себистон
#
#   Unnamed: 16  Name_Splitted
# 0         NaN  Трансформатор
# ...

# %%
# Changing the values of the columns
#reportsjan_feb["Тов группа"].value_counts()
reportsjan_feb["Тов группа"] = reportsjan_feb["Тов группа"].map({"Электроматериалы": "Electronic_materials","Стройматериал":"Construction_materials","Инструмент": "Instruments"})
reportsjan_feb.head()
# Out:
#        Код       Дата  № док  Поставщик                    Наименование  \
# 0  27654.0 2022-01-01    1.0  Внш Давид     Трансформатор ТМГ 250/10кВТ
# 1  27654.0 2022-01-01    1.0  Внш Давид     Трансформатор ТМГ 630/10кВТ
# 2  27654.0 2022-01-01    1.0  Внш Давид      Трансформатор ТМГ 100/6кВТ
# 3  27655.0 2022-01-01    2.0  Внш Давид  Компас Горно геологический ГГК
# 4  27656.0 2022-01-01    3.0  Внш Давид             Преобразователь ИД3
#
#      Абрев            Тов группа Ед Изм  Кол-во      Цена     Сумма Срок   \
# 0  30363.0  Electronic_materials     шт     1.0   65770.0   65770.0   NaT
# 1  30364.0  Electronic_materials     шт     1.0  118255.0  118255.0   NaT
# 2  30365.0  Electronic_materials     шт     1.0   42275.0   42275.0   NaT
# 3  30362.0                   NaN     шт     5.0    2700.0   13500.0   NaT
# 4  30358.0  Electronic_materials     шт     1.0    4070.0    4070.0   NaT
#
#   Серия                                             Произ.  МНН  \
# ...

# %%
# Rename two columns from the DF
reportsjan_feb.rename(columns={"Дата":"Date", "Поставщик":"International_Supplier"},inplace=True)
reportsjan_feb.head(2)
# Out:
#        Код       Date  № док International_Supplier  \
# 0  27654.0 2022-01-01    1.0              Внш Давид
# 1  27654.0 2022-01-01    1.0              Внш Давид
#
#                   Наименование    Абрев        Тов группа Ед Изм  Кол-во  \
# 0  Трансформатор ТМГ 250/10кВТ  30363.0  Электроматериалы     шт     1.0
# 1  Трансформатор ТМГ 630/10кВТ  30364.0  Электроматериалы     шт     1.0
#
#        Цена     Сумма Срок  Серия  \
# 0   65770.0   65770.0   NaT   NaN
# 1  118255.0  118255.0   NaT   NaN
#
#                                               Произ.  МНН           Вопросы  \
# 0  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 1  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
#
#   Unnamed: 16
# 0         NaN
# 1         NaN

# %%
# What if I want to change a row from specific column to another row -- ????
reportsjan_feb[0,"Наименование"] = reportsjan_feb["Наименование"].map({"Трансформатор ТМГ 250/10кВТ": "Трансформатор ТМГ 350/10кВТ"})

# %%
reportsjan_feb["Поставщик"].apply(make_lower("Вопросы=Anush"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User-PC\Desktop\Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000017?line=0'>1</a> reportsjan_feb["Поставщик"].apply(make_lower("Вопросы=Anush"))
#
# File c:\Users\User-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# ...

# %%
reportsjan_feb.apply(len)
# Out:
# Код             259
# Дата            259
# № док           259
# Поставщик       259
# Наименование    259
# Абрев           259
# Тов группа      259
# Ед Изм          259
# Кол-во          259
# Цена            259
# Сумма           259
# Срок            259
# Серия           259
# Произ.          259
# МНН             259
# Вопросы         259
# Unnamed: 16     259
# dtype: int64

# %%
## Apply a function to the DF # Our funtion didn't work out as I wanted

def make_lower(Вопросы):
    return Вопросы.upper()
##
reportsjan_feb["Наименование"].apply(make_lower)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User-PC\Desktop\Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb Cell 3' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000015?line=2'>3</a>     return Вопросы.upper()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000015?line=3'>4</a> ##
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000015?line=4'>5</a> reportsjan_feb["Наименование"].apply(make_lower)
#
# File c:\Users\User-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
# ...

# %%
# How to make the whole rows from a specific column to lowercase() or uppercase()
reportsjan_feb["Поставщик"] = reportsjan_feb["Поставщик"].str.upper()
reportsjan_feb.head()
# Out:
#        Код       Дата  № док  Поставщик                    Наименование  \
# 0  27654.0 2022-01-01    1.0  ВНШ ДАВИД     Трансформатор ТМГ 250/10кВТ
# 1  27654.0 2022-01-01    1.0  ВНШ ДАВИД     Трансформатор ТМГ 630/10кВТ
# 2  27654.0 2022-01-01    1.0  ВНШ ДАВИД      Трансформатор ТМГ 100/6кВТ
# 3  27655.0 2022-01-01    2.0  ВНШ ДАВИД  Компас Горно геологический ГГК
# 4  27656.0 2022-01-01    3.0  ВНШ ДАВИД             Преобразователь ИД3
#
#      Абрев        Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0  30363.0  Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  30364.0  Электроматериалы     шт     1.0  118255.0  118255.0   NaT   NaN
# 2  30365.0  Электроматериалы     шт     1.0   42275.0   42275.0   NaT   NaN
# 3  30362.0       Ос Средства     шт     5.0    2700.0   13500.0   NaT   NaN
# 4  30358.0  Электроматериалы     шт     1.0    4070.0    4070.0   NaT   NaN
#
# ...

# %%
# Let's assume that I want to change from 1st to 10th rows, from multiple columns --n???
reportsjan_feb.loc[([1:10]),["Тов группа","Произ."]] = ["Construction_Materials","LLC. Charkhi Gardun"]
reportsjan_feb.head(10)
# Out:
#   Input In [55]
#     reportsjan_feb.loc[([1]:[10]),["Тов группа","Произ."]] = ["Construction_Materials","LLC. Charkhi Gardun"]
#                            ^
# SyntaxError: invalid syntax

# %%
# Let's assume that I want to change several rows from multiple columns
reportsjan_feb.loc[[0,1],["Тов группа","Произ."]] = ["Construction_Materials","LLC. Charkhi Gardun"]
reportsjan_feb.head(2)
# Out:
#        Код       Дата  № док  Поставщик                 Наименование    Абрев  \
# 0  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 250/10кВТ  30363.0
# 1  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 630/10кВТ  30364.0
#
#                Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0  Construction_Materials     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  Construction_Materials     шт     1.0  118255.0  118255.0   NaT   NaN
#
#                 Произ.  МНН           Вопросы Unnamed: 16
# 0  LLC. Charkhi Gardun  NaN  Нуробод Оби гарм         NaN
# 1  LLC. Charkhi Gardun  NaN  Нуробод Оби гарм         NaN

# %%
# What if I want to changea row from multiple columns
reportsjan_feb.loc[1,["Тов группа","Произ."]] = ["Construction_Materials","LLC. Charkhi Gardun"]
reportsjan_feb.head(2)
# Out:
#        Код       Дата  № док  Поставщик                 Наименование    Абрев  \
# 0  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 250/10кВТ  30363.0
# 1  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 630/10кВТ  30364.0
#
#                Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0        Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  Construction_Materials     шт     1.0  118255.0  118255.0   NaT   NaN
#
#                                               Произ.  МНН           Вопросы  \
# 0  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 1                                LLC. Charkhi Gardun  NaN  Нуробод Оби гарм
#
#   Unnamed: 16
# 0         NaN
# 1         NaN

# %%
# How to change a row from a specific column
reportsjan_feb.loc[1,"Поставщик"] ="Внш_Маха"
reportsjan_feb.head(2)
# Out:
#        Код       Дата  № док  Поставщик                 Наименование    Абрев  \
# 0  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 250/10кВТ  30363.0
# 1  27654.0 2022-01-01    1.0   Внш_Маха  Трансформатор ТМГ 630/10кВТ  30364.0
#
#          Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0  Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  Электроматериалы     шт     1.0  118255.0  118255.0   NaT   NaN
#
#                                               Произ.  МНН           Вопросы  \
# 0  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 1  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
#
#   Unnamed: 16
# 0         NaN
# 1         NaN

# %%
# Let's update a specific row
reportsjan_feb.loc[1] = ['202020', "2020-01-2012", "2.0", "Внш Anush", "Трансформатор ТМГ 230/10кВТ", "	30354.0", "Электроматериалы", "шт", "5", "122255.0","118255.0", "NaT", "NaN", "Чирчикский трансформаторный завод Контракт:TG..", "NaN", "Нуробод Оби гарм", "NaN"]
reportsjan_feb.head(2)
# Out:
#        Код                 Дата № док  Поставщик                 Наименование  \
# 0  27654.0  2022-01-01 00:00:00   1.0  Внш Давид  Трансформатор ТМГ 250/10кВТ
# 1   202020         2020-01-2012   2.0  Внш Anush  Трансформатор ТМГ 230/10кВТ
#
#        Абрев        Тов группа Ед Изм Кол-во      Цена     Сумма Срок  Серия  \
# 0    30363.0  Электроматериалы     шт    1.0   65770.0   65770.0   NaT   NaN
# 1  \t30354.0  Электроматериалы     шт      5  122255.0  118255.0   NaT   NaN
#
#                                               Произ.  МНН           Вопросы  \
# 0  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 1    Чирчикский трансформаторный завод Контракт:TG..  NaN  Нуробод Оби гарм
#
#   Unnamed: 16
# 0         NaN
# 1         NaN

# %%
# Get a specific row
reportsjan_feb.loc[1]
# Out:
# Код                                                       27654.0
# Дата                                          2022-01-01 00:00:00
# № док                                                         1.0
# Поставщик                                               Внш Давид
# Наименование                          Трансформатор ТМГ 630/10кВТ
# Абрев                                                     30364.0
# Тов группа                                       Электроматериалы
# Ед Изм                                                         шт
# Кол-во                                                        1.0
# Цена                                                     118255.0
# Сумма                                                    118255.0
# Срок                                                          NaT
# Серия                                                         NaN
# Произ.          Чирчикский трансформаторный завод  Контракт:TG...
# ...

# %%
## Add "_" instead of spaces
reportsjan_feb.columns.str.replace(" ", "_")
# Out:
# Index(['Код', 'Дата', '№_док', 'Поставщик', 'Наименование', 'Абрев',
#        'Тов_группа', 'Ед_Изм', 'Кол-во', 'Цена', 'Сумма', 'Срок_', 'Серия',
#        'Произ.', 'МНН', 'Вопросы', 'Unnamed:_16'],
#       dtype='object')

# %%
# Rename column names
# For instance
reportsjan_feb.rename(columns={"Дата": "Date","Поставщик":"International_Supplier" })
# Out:
#          Код       Date  № док International_Supplier  \
# 0    27654.0 2022-01-01    1.0              Внш Давид
# 1    27654.0 2022-01-01    1.0              Внш Давид
# 2    27654.0 2022-01-01    1.0              Внш Давид
# 3    27655.0 2022-01-01    2.0              Внш Давид
# 4    27656.0 2022-01-01    3.0              Внш Давид
# ..       ...        ...    ...                    ...
# 254  28896.0 2022-02-22    1.0    Внш Хайруллоев Боир
# 255  28898.0 2022-02-28    1.0    Внш Хайруллоев Боир
# 256      NaN        NaT    NaN                    NaN
# 257      NaN        NaT    NaN                    NaN
# 258      NaN        NaT    NaN                    NaN
#
#                            Наименование    Абрев        Тов группа Ед Изм  \
# 0           Трансформатор ТМГ 250/10кВТ  30363.0  Электроматериалы     шт
# 1           Трансформатор ТМГ 630/10кВТ  30364.0  Электроматериалы     шт
# 2            Трансформатор ТМГ 100/6кВТ  30365.0  Электроматериалы     шт
# ...

# %%
# Use comprehesion to change all columns Names to uppercase
# Use comprehesion to change all columns Names to lowercase

#reportsjan_feb.columns= [x.upper() for x in reportsjan_feb.columns]
reportsjan_feb.columns= [x.lower() for x in reportsjan_feb.columns]
reportsjan_feb.head()
# Out:
#        код       дата  № док  поставщик                    наименование  \
# 0  27654.0 2022-01-01    1.0  Внш Давид     Трансформатор ТМГ 250/10кВТ
# 1  27654.0 2022-01-01    1.0  Внш Давид     Трансформатор ТМГ 630/10кВТ
# 2  27654.0 2022-01-01    1.0  Внш Давид      Трансформатор ТМГ 100/6кВТ
# 3  27655.0 2022-01-01    2.0  Внш Давид  Компас Горно геологический ГГК
# 4  27656.0 2022-01-01    3.0  Внш Давид             Преобразователь ИД3
#
#      абрев        тов группа ед изм  кол-во      цена     сумма срок  серия  \
# 0  30363.0  Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  30364.0  Электроматериалы     шт     1.0  118255.0  118255.0   NaT   NaN
# 2  30365.0  Электроматериалы     шт     1.0   42275.0   42275.0   NaT   NaN
# 3  30362.0       Ос Средства     шт     5.0    2700.0   13500.0   NaT   NaN
# 4  30358.0  Электроматериалы     шт     1.0    4070.0    4070.0   NaT   NaN
#
# ...

# %%
## Change the Column names (all of the columns)
jan_feb_2022_reports.columns["Наименование", "Сумма по полю Сумма","Сумма по полю Кол-во","Empty","Наименование2","Сумма о полю Сумма2","Diff6", "Whatever"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\User-PC\Desktop\Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000002?line=0'>1</a> ## Change the Column names (all of the columns)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Again_Pandas_Updating_Rows_and_Columns.ipynb#ch0000002?line=1'>2</a> jan_feb_2022_reports.columns["Наименование", "Сумма по полю Сумма","Сумма по полю Кол-во","Empty","Наименование2","Сумма о полю Сумма2","Diff6", "Whatever"]
#
# File c:\Users\User-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5055, in Index.__getitem__(self, key)
#    5048 if com.is_bool_indexer(key):
# ...

# %%
reportsjan_feb.head()
# Out:
#        Код       Дата  № док  Поставщик                    Наименование  \
# 0  27654.0 2022-01-01    1.0  Внш Давид     Трансформатор ТМГ 250/10кВТ
# 1  27654.0 2022-01-01    1.0  Внш Давид     Трансформатор ТМГ 630/10кВТ
# 2  27654.0 2022-01-01    1.0  Внш Давид      Трансформатор ТМГ 100/6кВТ
# 3  27655.0 2022-01-01    2.0  Внш Давид  Компас Горно геологический ГГК
# 4  27656.0 2022-01-01    3.0  Внш Давид             Преобразователь ИД3
#
#      Абрев        Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0  30363.0  Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  30364.0  Электроматериалы     шт     1.0  118255.0  118255.0   NaT   NaN
# 2  30365.0  Электроматериалы     шт     1.0   42275.0   42275.0   NaT   NaN
# 3  30362.0       Ос Средства     шт     5.0    2700.0   13500.0   NaT   NaN
# 4  30358.0  Электроматериалы     шт     1.0    4070.0    4070.0   NaT   NaN
#
# ...

# %%
# Импортируйте pandas\n"
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Получите данные из файла olympics.csv
olympics = pd.read_csv("olympics.csv")
olympics.head(5)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# # Посмотрите на первые 10 строк данных\n
olympics.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# ...

# %%
# Посмотрите на последние 6 строк данных\n"
olympics.tail(6)
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R    KHUSHTOV, Aslanbek
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29210  RUS    Men   84 - 96kg            M    Gold
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
# # Посмотрите на информацию о данных\n
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
## Посмотрите на количество строк и столбцов в данных\n
olympics.shape
# Out:
# (29216, 10)

# %%
# # Посмотрите на описательную статистику данных\n
olympics.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %%
# # Вытащите из данных названия всех столбцов\n
olympics.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'NOC', 'Gender',
#        'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %%
# Отсортируйте данные по столбцу 'Edition' по возрастанию - Review Sort_Values
olympics.sort_values(by="Edition",ascending=True)
# Out:
#           City  Edition       Sport       Discipline               Athlete  \
# 0       Athens     1896    Aquatics         Swimming         HAJOS, Alfred
# 97      Athens     1896  Gymnastics      Artistic G.   LOUNDRAS, Dimitrios
# 98      Athens     1896  Gymnastics      Artistic G.  MITROPOULOS, Ioannis
# 99      Athens     1896  Gymnastics      Artistic G.        BÖCKER, Konrad
# 100     Athens     1896  Gymnastics      Artistic G.        FLATOW, Alfred
# ...        ...      ...         ...              ...                   ...
# 27847  Beijing     2008  Basketball       Basketball       JIMENEZ, Carlos
# 27846  Beijing     2008  Basketball       Basketball            GASOL, Pau
# 27845  Beijing     2008  Basketball       Basketball           GASOL, Marc
# 27858  Beijing     2008  Basketball       Basketball        KUZINA, Marina
# 29215  Beijing     2008   Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                Event Event_gender   Medal
# ...

# %%
## Отсортируйте данные по столбцу \"Gender\", чтобы сначала были \"Women\", а потом \"Men\" и по столбцу \"Medal\" в порядке \"Bronze\", \"Gold\", \"Silver\".\n",
## Сохраните результат в переменную olympics_sorted_gen_med\n",
olympics.sort_values(by=["Gender", "Medal"], ascending=[True,True])
# Out:
#           City  Edition          Sport       Discipline  \
# 2       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# 11      Athens     1896      Athletics        Athletics
# 12      Athens     1896      Athletics        Athletics
# ...        ...      ...            ...              ...
# 29135  Beijing     2008  Weightlifting    Weightlifting
# 29148  Beijing     2008      Wrestling  Wrestling Free.
# 29156  Beijing     2008      Wrestling  Wrestling Free.
# 29164  Beijing     2008      Wrestling  Wrestling Free.
# 29172  Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender                       Event  \
# 2          DRIVAS, Dimitrios  GRE    Men  100m freestyle for sailors
# 5      CHOROPHAS, Efstathios  GRE    Men             1200m freestyle
# 8      CHOROPHAS, Efstathios  GRE    Men              400m freestyle
# ...

# %%
## Из olympics вытащите только столбцы \"City\", \"Discipline\", \"Medal\" в переменную selected_cols и посмотрите первые 5 строк\n"
selected_cols = olympics[["City", "Discipline", "Medal"]]
selected_cols.head(5)
# Out:
#      City Discipline   Medal
# 0  Athens   Swimming    Gold
# 1  Athens   Swimming  Silver
# 2  Athens   Swimming  Bronze
# 3  Athens   Swimming    Gold
# 4  Athens   Swimming  Silver

# %%
### Из olympics вытащите только строки в которых значение \"Medal\" равно \"Gold\"\n
filtered_medal = olympics["Medal"] == "Gold"
olympics[filtered_medal]
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
### Из olympics вытащите только строки в которых значение \"City\" равно \"London\" или \"Rio\" и посмотрите первые 5 строк\n
#filtered_city = olympics["City"] == [["London", "Rio"]]
# We have no Rio in the dataset
olympics["City"].value_counts()
filtered_city = olympics["City"] == "London"
olympics[filtered_city]
# Out:
#         City  Edition      Sport       Discipline                  Athlete  \
# 1133  London     1908   Aquatics           Diving         SPANGBERG, Arvid
# 1134  London     1908   Aquatics           Diving       JOHANSSON, Hjalmar
# 1135  London     1908   Aquatics           Diving          MALMSTRÖM, Karl
# 1136  London     1908   Aquatics           Diving  GAIDZIK, George William
# 1137  London     1908   Aquatics           Diving            WALZ, Gottlob
# ...      ...      ...        ...              ...                      ...
# 8013  London     1948  Wrestling  Wrestling Gre-R           GRÖNBERG, Axel
# 8014  London     1948  Wrestling  Wrestling Gre-R           TAYFUR, Muhlis
# 8015  London     1948  Wrestling  Wrestling Gre-R           ORABI, Ibrahim
# 8016  London     1948  Wrestling  Wrestling Gre-R       NILSSON, Karl-Erik
# 8017  London     1948  Wrestling  Wrestling Gre-R    GRÖNDAHL, Kelpo Olavi
#
#       NOC Gender                          Event Event_gender   Medal
# ...

# %%
### Из olympics вытащите только строки в которых значение \"City\" равно \"London\" или \"Rio\" и посмотрите первые 5 строк\n
filtered_city = (olympics["City"] == "London") | (olympics["City"] == "Rio")
 #We have no Rio in the dataset
olympics[filtered_city]
# Out:
#         City  Edition      Sport       Discipline                  Athlete  \
# 1133  London     1908   Aquatics           Diving         SPANGBERG, Arvid
# 1134  London     1908   Aquatics           Diving       JOHANSSON, Hjalmar
# 1135  London     1908   Aquatics           Diving          MALMSTRÖM, Karl
# 1136  London     1908   Aquatics           Diving  GAIDZIK, George William
# 1137  London     1908   Aquatics           Diving            WALZ, Gottlob
# ...      ...      ...        ...              ...                      ...
# 8013  London     1948  Wrestling  Wrestling Gre-R           GRÖNBERG, Axel
# 8014  London     1948  Wrestling  Wrestling Gre-R           TAYFUR, Muhlis
# 8015  London     1948  Wrestling  Wrestling Gre-R           ORABI, Ibrahim
# 8016  London     1948  Wrestling  Wrestling Gre-R       NILSSON, Karl-Erik
# 8017  London     1948  Wrestling  Wrestling Gre-R    GRÖNDAHL, Kelpo Olavi
#
#       NOC Gender                          Event Event_gender   Medal
# ...

# %%
##  Из olympics вытащите только строки в которых значение \"Edition\" 
# #равно \"2008\" и \"Medal\" равно \"Silver\"\n"
filtered_edition = (olympics["Edition"] == 2008) & (olympics["Medal"] == "Silver")
olympics[filtered_edition]
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 27176  Beijing     2008   Aquatics           Diving          ZHOU, Luxin  CHN
# 27179  Beijing     2008   Aquatics           Diving      HEYMANS, Emilie  CAN
# 27182  Beijing     2008   Aquatics           Diving  DESPATIE, Alexandre  CAN
# 27185  Beijing     2008   Aquatics           Diving     PAKHALINA, Julia  RUS
# 27190  Beijing     2008   Aquatics           Diving    HAUSDING, Patrick  GER
# ...        ...      ...        ...              ...                  ...  ...
# 29200  Beijing     2008  Wrestling  Wrestling Gre-R   BEGALIEV, Kanatbek  KGZ
# 29204  Beijing     2008  Wrestling  Wrestling Gre-R     CHANG, Yongxiang  CHN
# 29207  Beijing     2008  Wrestling  Wrestling Gre-R        FODOR, Zoltan  HUN
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R       ENGLICH, Mirko  GER
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R       BAROEV, Khasan  RUS
#
# ...

# %%
# Найдите строки в которых содержится слово \"Swimming\" 
# #в столбце \"Discipline\
cotains_swimming = olympics["Discipline"].str.contains("Swimming")
olympics[cotains_swimming]
# Out:
#           City  Edition     Sport Discipline                   Athlete  NOC  \
# 0       Athens     1896  Aquatics   Swimming             HAJOS, Alfred  HUN
# 1       Athens     1896  Aquatics   Swimming          HERSCHMANN, Otto  AUT
# 2       Athens     1896  Aquatics   Swimming         DRIVAS, Dimitrios  GRE
# 3       Athens     1896  Aquatics   Swimming        MALOKINIS, Ioannis  GRE
# 4       Athens     1896  Aquatics   Swimming        CHASAPIS, Spiridon  GRE
# ...        ...      ...       ...        ...                       ...  ...
# 27405  Beijing     2008  Aquatics   Swimming  VAN DER WEIJDEN, Maarten  NED
# 27406  Beijing     2008  Aquatics   Swimming             DAVIES, David  GBR
# 27407  Beijing     2008  Aquatics   Swimming         PATTEN, Cassandra  GBR
# 27408  Beijing     2008  Aquatics   Swimming          ILCHENKO, Larisa  RUS
# 27409  Beijing     2008  Aquatics   Swimming          PAYNE, Keri-Anne  GBR
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
reportsjan_feb =pd.read_excel("For_Pandas_Original_DF.xlsx", sheet_name = "внешный")
jan_feb_2022_reports = pd.read_excel("For_Pandas_Original_DF.xlsx")
reportsjan_feb.head(2)
#reportsjan_feb.dtypes
# Out:
#        Код       Дата  № док  Поставщик                 Наименование    Абрев  \
# 0  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 250/10кВТ  30363.0
# 1  27654.0 2022-01-01    1.0  Внш Давид  Трансформатор ТМГ 630/10кВТ  30364.0
#
#          Тов группа Ед Изм  Кол-во      Цена     Сумма Срок  Серия  \
# 0  Электроматериалы     шт     1.0   65770.0   65770.0   NaT   NaN
# 1  Электроматериалы     шт     1.0  118255.0  118255.0   NaT   NaN
#
#                                               Произ.  МНН           Вопросы  \
# 0  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
# 1  Чирчикский трансформаторный завод  Контракт:TG...  NaN  Нуробод Оби гарм
#
#   Unnamed: 16
# 0         NaN
# 1         NaN

# %%
# I want to see the largest and smallest withing my tbl
reportsjan_feb.nlargest(10,["Сумма"])
reportsjan_feb.nsmallest(10,["Сумма"])
# Out:
#          Код       Дата  № док            Поставщик  \
# 102  28265.0 2022-01-31    1.0    Внш Очилов Сухроб
# 103  28265.0 2022-01-31    1.0    Внш Очилов Сухроб
# 100  28265.0 2022-01-31    1.0    Внш Очилов Сухроб
# 99   28265.0 2022-01-31    1.0    Внш Очилов Сухроб
# 101  28265.0 2022-01-31    1.0    Внш Очилов Сухроб
# 80   28062.0 2022-01-27    1.0  Внш Хайруллоев Боир
# 98   28265.0 2022-01-31    1.0    Внш Очилов Сухроб
# 205  28793.0 2022-02-05    1.0   Внш Рахимов Шавкат
# 206  28793.0 2022-02-05    1.0   Внш Рахимов Шавкат
# 67   28315.0 2022-01-15    1.0    Внш Мирзоев Фотех
#
#                                           Наименование    Абрев  \
# 102            Пакер инъекционный пластиковый 18х110мм  30600.0
# 103            Пакер инъекционный пластиковый 18х105мм  30599.0
# 100               Пакер инъекционный стальной 10х100мм  30602.0
# 99   Пакер инъекционный стальной с плоской головкой...  30603.0
# 101            Пакер инъекционный алюминиевый 10х100мм  30601.0
# ...

# %%
# Let's see the largest and smallest value in the DF
reportsjan_feb["Сумма"].nlargest(10)
#reportsjan_feb["Сумма"].nsmallest(10)
# Out:
# 257    7.650796e+07
# 256    7.617372e+07
# 187    1.864485e+07
# 156    3.913278e+06
# 237    3.502070e+06
# 116    2.112695e+06
# 229    1.795376e+06
# 219    1.707688e+06
# 239    1.644390e+06
# 186    1.640415e+06
# Name: Сумма, dtype: float64

# %%
# Bring the data_frame to its original values
#reportsjan_feb.head()
reportsjan_feb.sort_index()
# Out:
#          Код       Дата  № док            Поставщик  \
# 0    27654.0 2022-01-01    1.0            Внш Давид
# 1    27654.0 2022-01-01    1.0            Внш Давид
# 2    27654.0 2022-01-01    1.0            Внш Давид
# 3    27655.0 2022-01-01    2.0            Внш Давид
# 4    27656.0 2022-01-01    3.0            Внш Давид
# ..       ...        ...    ...                  ...
# 254  28896.0 2022-02-22    1.0  Внш Хайруллоев Боир
# 255  28898.0 2022-02-28    1.0  Внш Хайруллоев Боир
# 256      NaN        NaT    NaN                  NaN
# 257      NaN        NaT    NaN                  NaN
# 258      NaN        NaT    NaN                  NaN
#
#                            Наименование    Абрев        Тов группа Ед Изм  \
# 0           Трансформатор ТМГ 250/10кВТ  30363.0  Электроматериалы     шт
# 1           Трансформатор ТМГ 630/10кВТ  30364.0  Электроматериалы     шт
# 2            Трансформатор ТМГ 100/6кВТ  30365.0  Электроматериалы     шт
# ...

# %%
# Sort Multiple Columns but each of them should be sorted by different order 
reportsjan_feb.sort_values(by=["Поставщик","Сумма"], ascending= [True, False],inplace=True)

# %%
# Sort Multiple Columns
reportsjan_feb.sort_values(by=["Поставщик","Сумма"], ascending= False)
# Out:
#          Код       Дата  № док    Поставщик  \
# 73   27870.0 2022-01-18    1.0  Внш Хувайдо
# 74   27871.0 2022-01-18    2.0  Внш Хувайдо
# 14   27868.0 2022-01-01    1.0  Внш Хувайдо
# 13   27868.0 2022-01-01    1.0  Внш Хувайдо
# 15   27868.0 2022-01-01    1.0  Внш Хувайдо
# ..       ...        ...    ...          ...
# 59   27658.0 2022-01-10    2.0  Внт Фирдавс
# 60   27658.0 2022-01-10    2.0  Внт Фирдавс
# 257      NaN        NaT    NaN          NaN
# 256      NaN        NaT    NaN          NaN
# 258      NaN        NaT    NaN          NaN
#
#                              Наименование    Абрев     Тов группа Ед Изм  \
# 73                        Арматура А3 Ф14   2647.0  Стройматериал      т
# 74                        Арматура А3 Ф14   2647.0  Стройматериал      т
# 14   Футеровка (№ черт. 02.590.00.02) 592  18813.0  Стройматериал     шт
# 13   Футеровка (№ черт. 02.590.00.01) 591  18812.0  Стройматериал     шт
# ...

# %%
# Sort a Column
reportsjan_feb.sort_values(by="Наименование", ascending = False)
reportsjan_feb.head(10)
# Out:
#        Код       Дата  № док  Поставщик                    Наименование  \
# 0  27654.0 2022-01-01    1.0  Внш Давид     Трансформатор ТМГ 250/10кВТ
# 1  27654.0 2022-01-01    1.0  Внш Давид     Трансформатор ТМГ 630/10кВТ
# 2  27654.0 2022-01-01    1.0  Внш Давид      Трансформатор ТМГ 100/6кВТ
# 3  27655.0 2022-01-01    2.0  Внш Давид  Компас Горно геологический ГГК
# 4  27656.0 2022-01-01    3.0  Внш Давид             Преобразователь ИД3
# 5  27656.0 2022-01-01    3.0  Внш Давид             Преобразователь ДА2
# 6  27656.0 2022-01-01    3.0  Внш Давид              Преобразователь ДШ
# 7  27656.0 2022-01-01    3.0  Внш Давид             Преобразователь ДКУ
# 8  27657.0 2022-01-01    4.0  Внш Давид                Провод АС 185/43
# 9  27657.0 2022-01-01    4.0  Внш Давид               Провод АС 185/128
#
#      Абрев        Тов группа Ед Изм  Кол-во           Цена         Сумма  \
# 0  30363.0  Электроматериалы     шт   1.000   65770.000000   65770.00000
# ...

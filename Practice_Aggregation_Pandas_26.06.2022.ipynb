# %%
import pandas as pd
import numpy as np

# %%
results_schema = pd.read_csv("survey_results_schema.csv")
results_public = pd.read_csv("survey_results_public.csv")

# %%
#results_schema.head(4)
results_public.head(4)
#results_public["Country"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                                 Slovakia
# 1                                              Netherlands
# 2                                       Russian Federation
# 3                                                  Austria
# 4        United Kingdom of Great Britain and Northern I...
#                                ...
# 83434                             United States of America
# 83435                                                Benin
# 83436                             United States of America
# 83437                                               Canada
# 83438                                               Brazil
# Name: Country, Length: 83439, dtype: object>

# %%
# Grouping and Aggregating Data
#First, Find Median
results_public["ConvertedCompYearly"].median()
# Out:
# 56211.0

# %%
# Find median for the whole Dataframe, all columns that have anything numerical
results_public.median()
# Out:
# C:\Users\User-PC\AppData\Local\Temp\ipykernel_2604\3533872922.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   results_public.median()
# ResponseId             41720.0
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
# Show the descriptive statistics for the DF
results_public.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
# Count how many values are in the column, how many of each values are in the column
results_public["Gender"].value_counts()
# Out:
# Man                                                                                   74817
# Woman                                                                                  4120
# Prefer not to say                                                                      1442
# Non-binary, genderqueer, or gender non-conforming                                       690
# Or, in your own words:                                                                  413
# Man;Or, in your own words:                                                              268
# Man;Non-binary, genderqueer, or gender non-conforming                                   252
# Woman;Non-binary, genderqueer, or gender non-conforming                                 147
# Man;Woman                                                                                41
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                 21
# ...

# %%
# Count how many values are in the column, how many of each values are in the column, show in percentage
results_public["Gender"].value_counts(normalize=True)
# Out:
# Man                                                                                   0.909231
# Woman                                                                                 0.050069
# Prefer not to say                                                                     0.017524
# Non-binary, genderqueer, or gender non-conforming                                     0.008385
# Or, in your own words:                                                                0.005019
# Man;Or, in your own words:                                                            0.003257
# Man;Non-binary, genderqueer, or gender non-conforming                                 0.003062
# Woman;Non-binary, genderqueer, or gender non-conforming                               0.001786
# Man;Woman                                                                             0.000498
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:              0.000255
# ...

# %%
# Grouping the Data
# Groupby() = Split - Apply function - Combine Results
results_public.head(2)
# Out:
#    ResponseId                              MainBranch  \
# 0           1          I am a developer by profession
# 1           2  I am a student who is learning to code
#
#                                           Employment      Country US_State  \
# 0  Independent contractor, freelancer, or self-em...     Slovakia      NaN
# 1                                 Student, full-time  Netherlands      NaN
#
#   UK_Country                                            EdLevel  \
# 0        NaN  Secondary school (e.g. American high school, G...
# 1        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# 0  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...       NaN
# 1  11 - 17 years  Other online resources (ex: videos, blogs, etc...         7
#
#    ...              Age Gender Trans                Sexuality  \
# 0  ...  25-34 years old    Man    No  Straight / Heterosexual
# ...

# %%
# Let's groupby countries
country_group = results_public.groupby(by=["Country"])
country_group

# %%
# Let's see the result of groupby # It looks like a filter, but it's better
country_group.get_group("United States of America")
# Out:
#        ResponseId                              MainBranch  \
# 5               6  I am a student who is learning to code
# 6               7             I code primarily as a hobby
# 15             16  I am a student who is learning to code
# 36             37          I am a developer by profession
# 37             38          I am a developer by profession
# ...           ...                                     ...
# 83427       83428          I am a developer by profession
# 83429       83430             I code primarily as a hobby
# 83430       83431          I am a developer by profession
# 83434       83435          I am a developer by profession
# 83436       83437          I am a developer by profession
#
#                                Employment                   Country  \
# 5                      Student, part-time  United States of America
# 6                     I prefer not to say  United States of America
# ...

# %%
# Filter out the countries
filt= results_public["Country"] == "India"
results_public.loc[filt]["LearnCode"].value_counts()
# Out:
# School                                                                                                                                                           1060
# Other online resources (ex: videos, blogs, etc)                                                                                                                   600
# Other online resources (ex: videos, blogs, etc);Online Courses or Certification                                                                                   392
# School;Books / Physical media                                                                                                                                     347
# Other online resources (ex: videos, blogs, etc);School;Online Courses or Certification;Books / Physical media                                                     340
# ...

# %%
## What if I want to see the aforementioned for Employment by groupby
country_group["LearnCode"].value_counts().tail(10)
## As we can see, it broke down each counry
# Out:
# Country   LearnCode
# Zimbabwe  Other online resources (ex: videos, blogs, etc);Online Forum;Other (please specify):;Books / Physical media                   1
#           Other online resources (ex: videos, blogs, etc);School;Books / Physical media                                                 1
#           Other online resources (ex: videos, blogs, etc);School;Online Courses or Certification;Colleague;Books / Physical media       1
#           Other online resources (ex: videos, blogs, etc);School;Online Forum                                                           1
#           Other online resources (ex: videos, blogs, etc);School;Online Forum;Friend or family member                                   1
#           Other online resources (ex: videos, blogs, etc);School;Online Forum;Online Courses or Certification                           1
# ...

# %%
## What if I want to see for a specific country by using group by()
country_group["LearnCode"].value_counts().loc["United States of America"]
# Out:
# LearnCode
# School                                                                                                           1472
# School;Books / Physical media                                                                                     900
# Books / Physical media                                                                                            693
# Other online resources (ex: videos, blogs, etc);School;Books / Physical media                                     671
# Other online resources (ex: videos, blogs, etc)                                                                   532
#                                                                                                                  ...
# School;Friend or family member;Online Courses or Certification;Other (please specify):;Books / Physical media       1
# School;Friend or family member;Other (please specify):;Colleague;Books / Physical media                             1
# ...

# %%
# What if I wanted a median Salary for a specific country?
country_group["ConvertedCompYearly"].median()
# Out:
# Country
# Afghanistan                              9792.0
# Albania                                 15900.0
# Algeria                                  9875.0
# Andorra                                 94045.5
# Angola                                   9750.0
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                12678.0
# Yemen                                    3954.0
# Zambia                                   9816.0
# Zimbabwe                                 7200.0
# Name: ConvertedCompYearly, Length: 181, dtype: float64

# %%
# What if I wanted median, mean for salaries by each country?
country_group["ConvertedCompYearly"].agg(["median", "mean"])
# Out:
#                                        median          mean
# Country
# Afghanistan                            9792.0  2.794748e+06
# Albania                               15900.0  4.499814e+04
# Algeria                                9875.0  1.446114e+04
# Andorra                               94045.5  8.928200e+04
# Angola                                 9750.0  2.155680e+04
# ...                                       ...           ...
# Venezuela, Bolivarian Republic of...  12000.0  2.246505e+04
# Viet Nam                              12678.0  1.995289e+04
# Yemen                                  3954.0  5.628667e+03
# Zambia                                 9816.0  1.991491e+04
# Zimbabwe                               7200.0  1.141477e+04
#
# [181 rows x 2 columns]

# %%
## # What if I wanted median, mean for salaries by a specific country?
country_group["ConvertedCompYearly"].agg(["median", "mean"]).loc["United States of America"]
# Out:
# median    125000.00000
# mean      262993.89848
# Name: United States of America, dtype: float64

# %%
## I wanna know how many people are men in survey. How can I know how many people in United States of America know Java
new_filt = results_public["MentalHealth"]
results_public[new_filt].__str__.contains("disorder")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\User-PC\Desktop\Practice_Aggregation.ipynb Cell 18' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Aggregation.ipynb#ch0000017?line=0'>1</a> ## I wanna know how many people are men in survey. How can I know how many people in United States of America know Java
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Aggregation.ipynb#ch0000017?line=1'>2</a> new_filt = results_public["MentalHealth"]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Aggregation.ipynb#ch0000017?line=2'>3</a> results_public[new_filt].__str__.contains("disorder")
#
# File c:\Users\User-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
# ...

# %%
## Let's apply a function
country_group["MentalHealth"].apply(lambda X: X.str.contains("disorder").sum()).head(50)
# Out:
# Country
# Afghanistan                          21
# Albania                              13
# Algeria                               5
# Andorra                               4
# Angola                                7
# Argentina                            83
# Armenia                               7
# Australia                           391
# Austria                             113
# Azerbaijan                           10
# Bahamas                               3
# Bahrain                               1
# Bangladesh                          127
# Barbados                              1
# Belarus                              24
# Belgium                             136
# Belize                                1
# Benin                                 2
# Bhutan                                2
# Bolivia                               6
# Bosnia and Herzegovina               16
# Botswana                              0
# Brazil                              630
# ...

# %%
## What percentage of each country has disorder???
diorder_people = pd.concat(["Mental Health","Gender"],axis=column,sort="False")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User-PC\Desktop\Practice_Aggregation.ipynb Cell 20' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Aggregation.ipynb#ch0000019?line=0'>1</a> ## What percentage of each country has disorder
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User-PC/Desktop/Practice_Aggregation.ipynb#ch0000019?line=1'>2</a> diorder_people = pd.concat(["Mental Health","Gender"],axis=column,sort="False")
#
# NameError: name 'column' is not defined
